# %% [markdown]
# #### If-Else

# %%
Age = int(input("enter your age"))
if Age>=18:
    print("Great you are elidgble for medical insurance")
else:
   print("Sorry you are not elidgble for medical insurance")
# Out:
# enter your age 16
# Sorry you are not elidgble for medical insurance

# %%
user = input("Enter your user name")
if user == 'string':
    print("correct user name")
    password = int(input("Enter your password"))
    if password == 1234:
      print("Login succesfully")
    else:
      print("Invalid Password")
else:
  print("Invalid User name")
# Out:
# Enter your user name string
# correct user name
# Enter your password 1234
# Login succesfully

# %%
user = input("Enter the user name:")
if user == 'ali': 
    print("correct user name")
    password = int(input("Enter the password:"))
    if password == 1234:
      print("welcome")
    else:
      print("wrong password")
else:
 print("wrong user name")
# Out:
# Enter the user name: ali123
# wrong user name

# %%
user = input("Enter the user name:")
if user == 'ali': 
    print("correct user name")
    password = int(input("Enter the password:"))
    if password == 1234:
      print("welcome")
    else:
      print("wrong password")
else:
 print("wrong user name")
# Out:
# Enter the user name: ali
# correct user name
# Enter the password: 34455
# wrong password

# %%
user = input("Enter the user name:")
check = True
if user != 'ali':
 print("wrong user name") 
elif True:
 password = int(input("Enter the password:"))
 if password == 1234:
      check = True
      print("login succesful")
 else:
      print("wrong password")
else:
 print("wrong  name")
# Out:
# Enter the user name: ali
# Enter the password: 1234
# login succesful
